# %%
word = 'testing'
length = len(word)
middle = length // 2
if length % 2 == 1: # если длина нечетная
    print(word[middle])
else: # если длина четная
    print(word[middle - 1 : middle + 1])
    """ Задаем переменную word, в которой хранится наше слово. Вычисляем длину слова (команда len), сохраняем в переменную lenght. Находим индекс средней буквы (// это целочисленное деление), сохраняем в переменную middle. Проверяем четное или нечетное количество букв, для этого используем команду %, которая обозначает остаток от деления (например, 7 % 2 = 1). Далее используем оператор сравнения == (равно ли?), он возвращает True или False. Если (if) остаток от деления равен 1, то выводим среднюю букву (middle), а если нулю (четное), выводим две средние буквы (срез от middle-1 middle+1) """
# Out:
# t

# %%
boys = ['Peter', 'Alex', 'John', 'Arthur', 'Richard', 'Michael']
girls = ['Sveta', 'Kate', 'Liza', 'Kira', 'Emma']

def make_pairs(boys, girls):
    # Проверяем, равны ли длины списков
    if len(boys) != len(girls):
        print("Внимание, кто-то может остаться без пары!")
        return

# Сортируем списки по алфавиту
    boys_sorted = sorted(boys)
    girls_sorted = sorted(girls)

# Формируем пары
    pairs = list(zip(boys_sorted, girls_sorted))

# Выводим результат
    print("Идеальные пары:")
    for boy, girl in pairs:
        print(f"{boy} и {girl}")

# Вызов функции
make_pairs(boys, girls)
# Out:
# Внимание, кто-то может остаться без пары!

# %%
"""Комментарий: 
1. Первым делом мы определили списки
boys = ['x'...]
Здесь мы создаём два списка: boys и girls.
Списки содержат имена в виде строк.
Эти списки будут использоваться для формирования пар.
2. Далее мы определили функцию с помощью слова def и назвали ее make_pairs. Задали (boys, girls) как параметры функции, которые принимают списки имен.
3. Затем проверили длину списков с помощью команды len. != обозначает "не равно". Команда "return" завершает выполнение функции, если условие истинно.
4. Сортируем списки: sorted - встроенная функция Phyton, которая сортирует списки по алфавиту. Результаты сортировки сохраняются в новые переменные: boys_sorted и girls_sorted
5. Теперь формируем пары. zip(boys_sorted, girls_sorted) — функция, которая объединяет два списка в пары. list(zip(...)) — преобразует результат работы zip в список кортежей (пар).
6. Выводим результат: сначала выводим заголовок 'Идеальные пары', затем создаем цикл, который перебирает все пары из списка pairs (с помощью команды for). Далее команда print(f"{boy} и {girl}") выводит каждую пару в формате: "Имя_юноши и Имя_девушки".
f"{boy} и {girl}" — f-строка, которая подставляет значения переменных boy и girl в строку.

Итог:

Списки: Хранят данные (имена).
Функция: Обрабатывает данные и выводит результат.
Условный оператор: Проверяет, можно ли формировать пары.
Сортировка: Упорядочивает имена по алфавиту.
Цикл: Перебирает пары и выводит их на экран"""
